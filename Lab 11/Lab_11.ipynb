# %% [markdown]
# # Abrar Ali
# ## ID 55843

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris, load_wine, make_classification
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# Set random seed for reproducibility
np.random.seed(42)

# %%
# Generate a custom binary classification dataset
print("=" * 60)
print("DATASET 1: CUSTOM BINARY CLASSIFICATION")
print("=" * 60)

X1, y1 = make_classification(
    n_samples=1000,
    n_features=4,
    n_informative=2,
    n_redundant=1,
    n_repeated=1,
    n_classes=2,
    n_clusters_per_class=1,
    random_state=42
)

# Split the dataset
X1_train, X1_test, y1_train, y1_test = train_test_split(
    X1, y1, test_size=0.3, random_state=42
)

# Create and train Gaussian Naive Bayes model
gnb1 = GaussianNB()
gnb1.fit(X1_train, y1_train)

# Make predictions
y1_pred = gnb1.predict(X1_test)

# Evaluate the model
accuracy1 = accuracy_score(y1_test, y1_pred)
f1_1 = f1_score(y1_test, y1_pred)

print(f"Accuracy: {accuracy1:.4f}")
print(f"F1 Score: {f1_1:.4f}")
print("\nClassification Report:")
print(classification_report(y1_test, y1_pred))

# Plot confusion matrix
plt.figure(figsize=(8, 6)) # Changed figure size
cm1 = confusion_matrix(y1_test, y1_pred)
sns.heatmap(cm1, annot=True, fmt='d', cmap='Purples') # Changed colormap
plt.title('Custom Binary Classification: Confusion Matrix') # Changed title
plt.xlabel('Predicted Label') # Changed label
plt.ylabel('True Label') # Changed label
plt.tight_layout()
plt.show()
# Out:
# ...
# DATASET 1: CUSTOM BINARY CLASSIFICATION
# ...
# Accuracy: 0.8967
# F1 Score: 0.8864
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91       161
#            1       0.90      0.87      0.89       139
#
#     accuracy                           0.90       300
#    macro avg       0.90      0.89      0.90       300
# weighted avg       0.90      0.90      0.90       300

# %%
# Load Iris dataset (Multiclass)
print("\n" + "=" * 60)
print("DATASET 2: IRIS DATASET (MULTICLASS)")
print("=" * 60)

iris = load_iris()
X2, y2 = iris.data, iris.target

# Split the dataset
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, y2, test_size=0.3, random_state=42
)

# Create and train Gaussian Naive Bayes model
gnb2 = GaussianNB()
gnb2.fit(X2_train, y2_train)

# Make predictions
y2_pred = gnb2.predict(X2_test)

# Evaluate the model
accuracy2 = accuracy_score(y2_test, y2_pred)
f1_2 = f1_score(y2_test, y2_pred, average='weighted')

print(f"Accuracy: {accuracy2:.4f}")
print(f"F1 Score (weighted): {f1_2:.4f}")
print("\nClassification Report:")
print(classification_report(y2_test, y2_pred, target_names=iris.target_names))

# Plot confusion matrix
plt.figure(figsize=(8, 6)) # Added new figure
cm2 = confusion_matrix(y2_test, y2_pred)
sns.heatmap(cm2, annot=True, fmt='d', cmap='Oranges', # Changed colormap
            xticklabels=iris.target_names,
            yticklabels=iris.target_names)
plt.title('Iris Dataset: Confusion Matrix') # Changed title
plt.xlabel('Predicted Class') # Changed label
plt.ylabel('Actual Class') # Changed label
plt.tight_layout()
plt.show()
# Out:
# ...
# DATASET 2: IRIS DATASET (MULTICLASS)
# ...
# Accuracy: 0.9778
# F1 Score (weighted): 0.9777
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      0.92      0.96        13
#    virginica       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.97        45
# weighted avg       0.98      0.98      0.98        45

# %%
# Load Wine dataset (Multiclass)
print("\n" + "=" * 60)
print("DATASET 3: WINE DATASET (MULTICLASS)")
print("=" * 60)

wine = load_wine()
X3, y3 = wine.data, wine.target

# Split the dataset
X3_train, X3_test, y3_train, y3_test = train_test_split(
    X3, y3, test_size=0.3, random_state=42
)

# Create and train Gaussian Naive Bayes model
gnb3 = GaussianNB()
gnb3.fit(X3_train, y3_train)

# Make predictions
y3_pred = gnb3.predict(X3_test)

# Evaluate the model
accuracy3 = accuracy_score(y3_test, y3_pred)
f1_3 = f1_score(y3_test, y3_pred, average='weighted')

print(f"Accuracy: {accuracy3:.4f}")
print(f"F1 Score (weighted): {f1_3:.4f}")
print("\nClassification Report:")
print(classification_report(y3_test, y3_pred, target_names=wine.target_names))

# Plot confusion matrix
plt.figure(figsize=(8, 6)) # Added new figure
cm3 = confusion_matrix(y3_test, y3_pred)
sns.heatmap(cm3, annot=True, fmt='d', cmap='YlGn', # Changed colormap
            xticklabels=wine.target_names,
            yticklabels=wine.target_names)
plt.title('Wine Dataset: Confusion Matrix') # Changed title
plt.xlabel('Predicted Outcome') # Changed label
plt.ylabel('Actual Outcome') # Changed label

plt.tight_layout()
plt.show()
# Out:
# ...
# DATASET 3: WINE DATASET (MULTICLASS)
# ...
# Accuracy: 1.0000
# F1 Score (weighted): 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      class_0       1.00      1.00      1.00        19
#      class_1       1.00      1.00      1.00        21
#      class_2       1.00      1.00      1.00        14
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54

# %%
# Compare different Naive Bayes variants and parameters
print("\n" + "=" * 70)
print("COMPARISON OF DIFFERENT NAIVE BAYES VARIANTS AND PARAMETERS")
print("=" * 70)

# Use Iris dataset for comparison
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Different Naive Bayes classifiers
classifiers = {
    'Gaussian Naive Bayes': GaussianNB(),
    'Gaussian NB (var_smoothing=1e-9)': GaussianNB(var_smoothing=1e-9),
    'Gaussian NB (var_smoothing=1e-5)': GaussianNB(var_smoothing=1e-5),
}

# Apply different preprocessing
preprocessors = {
    'No Scaling': None,
    'Standard Scaling': StandardScaler(),
    'MinMax Scaling': MinMaxScaler()
}

results = []

for preproc_name, preprocessor in preprocessors.items():
    print(f"\n--- {preproc_name} ---")

    # Apply preprocessing if specified
    if preprocessor is not None:
        X_train_processed = preprocessor.fit_transform(X_train)
        X_test_processed = preprocessor.transform(X_test)
    else:
        X_train_processed = X_train.copy()
        X_test_processed = X_test.copy()

    for clf_name, classifier in classifiers.items():
        # Train classifier
        classifier.fit(X_train_processed, y_train)

        # Make predictions
        y_pred = classifier.predict(X_test_processed)

        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='weighted')

        results.append({
            'Preprocessor': preproc_name,
            'Classifier': clf_name,
            'Accuracy': accuracy,
            'F1 Score': f1
        })

        print(f"{clf_name}: Accuracy = {accuracy:.4f}, F1 = {f1:.4f}")

# Create results dataframe
results_df = pd.DataFrame(results)
print("\n" + "=" * 70)
print("SUMMARY OF RESULTS")
print("=" * 70)
print(results_df.to_string(index=False))
# Out:
# ...
# COMPARISON OF DIFFERENT NAIVE BAYES VARIANTS AND PARAMETERS
# ...
#
# --- No Scaling ---
# Gaussian Naive Bayes: Accuracy = 0.9778, F1 = 0.9777
# Gaussian NB (var_smoothing=1e-9): Accuracy = 0.9778, F1 = 0.9777
# Gaussian NB (var_smoothing=1e-5): Accuracy = 0.9778, F1 = 0.9777
#
# --- Standard Scaling ---
# Gaussian Naive Bayes: Accuracy = 0.9778, F1 = 0.9777
# Gaussian NB (var_smoothing=1e-9): Accuracy = 0.9778, F1 = 0.9777
# Gaussian NB (var_smoothing=1e-5): Accuracy = 0.9778, F1 = 0.9777
#
# --- MinMax Scaling ---
# Gaussian Naive Bayes: Accuracy = 0.9778, F1 = 0.9777
# Gaussian NB (var_smoothing=1e-9): Accuracy = 0.9778, F1 = 0.9777
# Gaussian NB (var_smoothing=1e-5): Accuracy = 0.9778, F1 = 0.9777
#
# ...
# SUMMARY OF RESULTS
# ...
#     Preprocessor                       Classifier  Accuracy  F1 Score
#       No Scaling             Gaussian Naive Bayes  0.977778  0.977745
#       No Scaling Gaussian NB (var_smoothing=1e-9)  0.977778  0.977745
# ...

# %%
# Advanced implementation with feature importance analysis
print("\n" + "=" * 70)
print("FEATURE ANALYSIS WITH NAIVE BAYES")
print("=" * 70)

# Use Wine dataset for feature analysis
wine = load_wine()
X, y = wine.data, wine.target
feature_names = wine.feature_names

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Gaussian Naive Bayes
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# Make predictions
y_pred = gnb.predict(X_test)

# Calculate feature importance (based on standard deviations)
feature_importance = np.std(gnb.theta_, axis=0)
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importance
}).sort_values('Importance', ascending=False)

print("Feature Importance (based on class-wise feature standard deviations):")
print(feature_importance_df.to_string(index=False))

# Plot feature importance
plt.figure(figsize=(10, 5)) # Changed figure size
plt.subplot(1, 2, 1)
sns.barplot(data=feature_importance_df, x='Importance', y='Feature', palette='magma') # Changed colormap
plt.title('Naive Bayes Feature Importance (Wine Dataset)') # Changed title
plt.xlabel('Feature Importance Score') # Changed label

# Plot class distributions for top 2 features
plt.subplot(1, 2, 2)
top_features = feature_importance_df.head(2)['Feature'].values
feature1_idx = list(feature_names).index(top_features[0])
feature2_idx = list(feature_names).index(top_features[1])

plt.scatter(X_train[:, feature1_idx], X_train[:, feature2_idx], c=y_train,
            cmap='plasma', alpha=0.7, edgecolors='w', s=50) # Changed colormap
plt.xlabel(top_features[0])
plt.ylabel(top_features[1])
plt.title(f'Feature Relationship: {top_features[0]} vs {top_features[1]}') # Changed title
plt.colorbar(label='Class Label') # Changed label

plt.tight_layout()
plt.show()

# Final model evaluation
print("\n" + "=" * 70)
print("FINAL COMPREHENSIVE MODEL EVALUATION")
print("=" * 70)

accuracy = accuracy_score(y_test, y_pred)
f1_weighted = f1_score(y_test, y_pred, average='weighted')
f1_macro = f1_score(y_test, y_pred, average='macro')

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score (Weighted): {f1_weighted:.4f}")
print(f"F1 Score (Macro): {f1_macro:.4f}")

print("\nDetailed Classification Report:")
print(classification_report(y_test, y_pred, target_names=wine.target_names))

# Final confusion matrix
plt.figure(figsize=(7, 5)) # Changed figure size
cm_final = confusion_matrix(y_test, y_pred)
sns.heatmap(cm_final, annot=True, fmt='d', cmap='rocket', # Changed colormap
            xticklabels=wine.target_names,
            yticklabels=wine.target_names)
plt.title('Wine Model: Final Confusion Matrix') # Changed title
plt.xlabel('Predicted Category') # Changed label
plt.ylabel('True Category') # Changed label
plt.show()
# Out:
# ...
# FEATURE ANALYSIS WITH NAIVE BAYES
# ...
# Feature Importance (based on class-wise feature standard deviations):
#                      Feature  Importance
#                      proline  246.229576
#                    magnesium    4.845919
#            alcalinity_of_ash    1.968045
#              color_intensity    1.684660
#                   flavanoids    0.905532
#                   malic_acid    0.654586
# od280/od315_of_diluted_wines    0.650345
#                      alcohol    0.617236
#                total_phenols    0.495025
#              proanthocyanins    0.350178
#                          hue    0.175088
#                          ash    0.084738
#         nonflavanoid_phenols    0.057598
# ...
# FINAL COMPREHENSIVE MODEL EVALUATION
# ...
# Accuracy: 1.0000
# F1 Score (Weighted): 1.0000
# F1 Score (Macro): 1.0000
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#      class_0       1.00      1.00      1.00        19
# ...

# %%
# Performance summary across all experiments
print("\n" + "=" * 70)
print("OVERALL PERFORMANCE SUMMARY")
print("=" * 70)

summary_data = {
    'Dataset': ['Custom Binary', 'Iris', 'Wine'],
    'Classes': [2, 3, 3],
    'Samples': [X1.shape[0], X2.shape[0], X3.shape[0]],
    'Features': [X1.shape[1], X2.shape[1], X3.shape[1]],
    'Accuracy': [accuracy1, accuracy2, accuracy3],
    'F1 Score': [f1_1, f1_2, f1_3]
}

summary_df = pd.DataFrame(summary_data)
print(summary_df.to_string(index=False))

# Plot performance comparison
plt.figure(figsize=(14, 6)) # Changed figure size

plt.subplot(1, 2, 1)
x_pos = np.arange(len(summary_df))
width = 0.35

plt.bar(x_pos - width/2, summary_df['Accuracy'], width, label='Accuracy', alpha=0.8) # Changed alpha
plt.bar(x_pos + width/2, summary_df['F1 Score'], width, label='F1 Score', alpha=0.8) # Changed alpha

plt.xlabel('Dataset Name') # Changed label
plt.ylabel('Performance Score') # Changed label
plt.title('Model Performance Across Different Datasets') # Changed title
plt.xticks(x_pos, summary_df['Dataset'])
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5) # Changed grid style and alpha

plt.subplot(1, 2, 2)
# Best performing configuration from parameter tuning
best_result = results_df.loc[results_df['Accuracy'].idxmax()]
best_config = f"{best_result['Preprocessor']}\n{best_result['Classifier']}"

configs = [f"Config {i+1}" for i in range(len(results_df))]
accuracies = results_df['Accuracy']

plt.bar(configs, accuracies, color='skyblue', alpha=0.8) # Changed color and alpha
plt.axhline(y=best_result['Accuracy'], color='darkgreen', linestyle='-.',
            label=f'Best: {best_result["Accuracy"]:.4f}') # Changed color and linestyle
plt.xlabel('Configuration Type') # Changed label
plt.ylabel('Accuracy Score') # Changed label
plt.title('Comparison of Naive Bayes Configurations') # Changed title
plt.xticks(rotation=45)
plt.legend()
plt.grid(axis='y', linestyle=':', alpha=0.6) # Changed grid style and alpha

plt.tight_layout()
plt.show()

print(f"\nBest Configuration:")
print(f"Preprocessor: {best_result['Preprocessor']}")
print(f"Classifier: {best_result['Classifier']}")
print(f"Accuracy: {best_result['Accuracy']:.4f}")
print(f"F1 Score: {best_result['F1 Score']:.4f}")
# Out:
# ...
# OVERALL PERFORMANCE SUMMARY
# ...
#       Dataset  Classes  Samples  Features  Accuracy  F1 Score
# Custom Binary        2     1000         4  0.896667  0.886447
#          Iris        3      150         4  0.977778  0.977745
#          Wine        3      178        13  1.000000  1.000000
# Best Configuration:
# Preprocessor: No Scaling
# Classifier: Gaussian Naive Bayes
# Accuracy: 0.9778
# F1 Score: 0.9777
